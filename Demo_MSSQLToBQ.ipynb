# %%
import pyodbc
import pandas as pd

import sqlalchemy
from sqlalchemy.engine import URL
from sqlalchemy.exc import SQLAlchemyError

# %%
_hostname ='shiredb\EESDB' 
_port=1433
_servicename = 'YIT-EES' 
_username = 'bigquery' 
_password = 'Phkpit[[.s,J'

# %%
cnxn = pyodbc.connect('DRIVER={SQL Server};SERVER='+_hostname +';DATABASE='+_servicename+';Port='+str(_port)+';UID='+_username+';PWD='+_password)

cursor = cnxn.cursor()

#start_date_query='2023-01-01'
start_date_query='2023-08-11 18:27:56.437'
# select 26 rows from SQL table to insert in dataframe.
query = f" SELECT  * FROM bigdata.vw_IPF  where last_update_date>='{start_date_query}';"
df = pd.read_sql(query, cnxn)
print(df.info())
df.tail()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 3 entries, 0 to 2
# Data columns (total 77 columns):
#  #   Column                            Non-Null Count  Dtype
# ---  ------                            --------------  -----
#  0   IPF_ID                            3 non-null      int64
#  1   IPF_No                            3 non-null      object
#  2   IPF_Date                          3 non-null      datetime64[ns]
#  3   IPF_CreateBy                      3 non-null      object
#  4   IPF_CompanyCode                   3 non-null      object
#  5   Quotation_ID                      0 non-null      object
#  6   StatusCode                        3 non-null      object
#  7   StatusLevel                       3 non-null      int64
#  8   NextStatusCode                    3 non-null      object
#  9   NextStatusLevel                   3 non-null      int64
#  10  CancelDate                        1 non-null      datetime64[ns]
#  11  CancelBy                          1 non-null      object
#  12  IsDelete                          0 non-null      object
#  13  DeleteBy                          0 non-null      object
#  14  ApproveCompleteDate               1 non-null      datetime64[ns]
#  15  Seller_AdminUser                  3 non-null      object
#  16  Seller_DocTypeID                  3 non-null      int64
#  17  Seller_Org_ID                     3 non-null      int64
#  18  Seller_CompanyCode                3 non-null      object
#  19  Seller_DeptCode                   3 non-null      object
#  20  Seller_ProjectName                3 non-null      object
#  21  Seller_Salesrep_ID                0 non-null      object
#  22  Seller_Salesrep_NO                3 non-null      object
#  23  Seller_Salesrep_Name              3 non-null      object
#  24  Seller_Account_Code               3 non-null      object
#  25  Seller_CompleteDeliveryDate       0 non-null      object
#  26  Seller_CompleteDeliveryBy         0 non-null      object
#  27  Seller_ProjectStatus              0 non-null      object
#  28  Seller_RefProjectNo               3 non-null      object
#  29  Buyer_AdminUser                   3 non-null      object
#  30  Buyer_DocTypeID                   3 non-null      int64
#  31  Buyer_Org_ID                      3 non-null      int64
#  32  Buyer_Salesrep_ID                 0 non-null      object
#  33  Buyer_Salesrep_NO                 3 non-null      object
#  34  Buyer_Salesrep_Name               3 non-null      object
#  35  Buyer_CompanyCode                 3 non-null      object
#  36  Buyer_DeptCode                    3 non-null      object
#  37  Buyer_Account_Code                3 non-null      object
#  38  Buyer_PurchaseAmount              3 non-null      float64
#  39  Buyer_CustomerName                0 non-null      object
#  40  Buyer_CompleteDeliveryDate        0 non-null      object
#  41  Buyer_CompleteDeliveryBy          0 non-null      object
#  42  Buyer_ProjectStatus               0 non-null      object
#  43  Buyer_ItemCode                    1 non-null      object
#  44  Buyer_Account_Code_Project_Close  0 non-null      object
#  45  IPFType                           3 non-null      object
#  46  Maintenance_DateStart             3 non-null      datetime64[ns]
#  47  Maintenance_DateEnd               3 non-null      datetime64[ns]
#  48  Maintenance_Day                   3 non-null      int64
#  49  CostAmount                        3 non-null      float64
#  50  Sales_Amount                      3 non-null      float64
#  51  CurrencyCode                      3 non-null      object
#  52  Total_Quantity                    0 non-null      object
#  53  Total_Amount                      0 non-null      object
#  54  Description                       3 non-null      object
#  55  Remark                            1 non-null      object
#  56  Expend_Org_Id                     1 non-null      float64
#  57  Expend_ProjectNo                  1 non-null      object
#  58  Expend_TaskNo                     1 non-null      object
#  59  Expend_Type                       1 non-null      object
#  60  Expend_Date                       1 non-null      object
#  61  Expend_RefProjectNo               3 non-null      object
#  62  OMOrderNo                         0 non-null      object
#  63  IPF_ReferNo                       0 non-null      object
#  64  IPF_RefProjectNo                  1 non-null      object
#  65  CreateDate                        3 non-null      datetime64[ns]
#  66  CreateBy                          3 non-null      object
#  67  UpdateDate                        3 non-null      datetime64[ns]
#  68  UpdateBy                          3 non-null      object
#  69  RefNoDept                         3 non-null      object
#  70  DeliveryDatePlace                 0 non-null      object
#  71  Warranry                          0 non-null      object
#  72  IncidentQty                       0 non-null      object
#  73  ConfirmIncidentQty                0 non-null      object
#  74  Original_IPF_ID                   1 non-null      float64
#  75  creation_date                     3 non-null      datetime64[ns]
#  76  last_update_date                  3 non-null      datetime64[ns]
# dtypes: datetime64[ns](9), float64(5), int64(8), object(55)
# memory usage: 1.9+ KB
# None
# C:\Users\mis-bi-service\AppData\Local\Temp\2\ipykernel_11064\1987765917.py:9: UserWarning: pandas only supports SQLAlchemy connectable (engine/connection) or database string URI or sqlite3 DBAPI2 connection. Other DBAPI2 objects are not tested. Please consider using SQLAlchemy.
#   df = pd.read_sql(query, cnxn)
#    IPF_ID            IPF_No                IPF_Date IPF_CreateBy
# 0    1333  0311-0302-650046 2023-08-11 00:00:00.000      1002267  \
# 1    2213  0305-0201-660009 2023-08-15 09:51:26.990      1002011
# 2    2214  0305-0204-660002 2023-08-15 00:00:00.000      1002011
#
#   IPF_CompanyCode Quotation_ID StatusCode  StatusLevel NextStatusCode
# 0              11         None    POSTING           80        CONFIRM  \
# 1              11         None     CREATE           10         SUBMIT
# 2              11         None      APPV2           40          APPV2
#
#    NextStatusLevel  ...              UpdateDate UpdateBy    RefNoDept
# 0               70  ... 2023-08-11 18:27:56.437  1001423  NCQ/65-S092  \
# 1               20  ... 2023-08-15 09:51:26.990  1002011   GOQ/66-007
# 2               40  ... 2023-08-15 09:54:01.780  1002011   GOQ/66-007
#
#   DeliveryDatePlace Warranry IncidentQty  ConfirmIncidentQty  Original_IPF_ID
# 0              None     None        None                None              NaN  \
# 1              None     None        None                None              NaN
# 2              None     None        None                None           2213.0
#
#             creation_date        last_update_date
# 0 2022-09-23 14:35:33.450 2023-08-11 18:27:56.437
# 1 2023-08-15 09:51:26.990 2023-08-15 09:51:26.990
# 2 2023-08-15 09:53:25.357 2023-08-15 09:54:01.780
#
# [3 rows x 77 columns]

# %%
connection_url = URL.create(
    drivername="mssql+pyodbc",
    username=_username,
    password=_password,
    host=_hostname,
    port=_port,
    database=_servicename,
    query={"driver": "SQL Server"}
)

engine = sqlalchemy.create_engine(connection_url)

df2= pd.read_sql(query, engine)
df2.tail()
# Out:
# ---------------------------------------------------------------------------
# OperationalError                          Traceback (most recent call last)
# File ~\AppData\Roaming\Python\Python39\site-packages\sqlalchemy\engine\base.py:145, in Connection.__init__(self, engine, connection, _has_events, _allow_revalidate, _allow_autobegin)
#     144 try:
# --> 145     self._dbapi_connection = engine.raw_connection()
#     146 except dialect.loaded_dbapi.Error as err:
#
# File ~\AppData\Roaming\Python\Python39\site-packages\sqlalchemy\engine\base.py:3288, in Engine.raw_connection(self)
#    3267 """Return a "raw" DBAPI connection from the connection pool.
#    3268
#    3269 The returned object is a proxied version of the DBAPI
#    (...)
#    3286
#    3287 """
# -> 3288 return self.pool.connect()
#
# File ~\AppData\Roaming\Python\Python39\site-packages\sqlalchemy\pool\base.py:452, in Pool.connect(self)
#     445 """Return a DBAPI connection from the pool.
#     446
#     447 The connection is instrumented such that when its
#    (...)
#     450
#     451 """
# --> 452 return _ConnectionFairy._checkout(self)
#
# File ~\AppData\Roaming\Python\Python39\site-packages\sqlalchemy\pool\base.py:1267, in _ConnectionFairy._checkout(cls, pool, threadconns, fairy)
#    1266 if not fairy:
# -> 1267     fairy = _ConnectionRecord.checkout(pool)
#    1269     if threadconns is not None:
#
# File ~\AppData\Roaming\Python\Python39\site-packages\sqlalchemy\pool\base.py:716, in _ConnectionRecord.checkout(cls, pool)
#     715 else:
# --> 716     rec = pool._do_get()
#     718 try:
#
# File ~\AppData\Roaming\Python\Python39\site-packages\sqlalchemy\pool\impl.py:170, in QueuePool._do_get(self)
#     169 with util.safe_reraise():
# --> 170     self._dec_overflow()
#     171 raise
#
# File ~\AppData\Roaming\Python\Python39\site-packages\sqlalchemy\util\langhelpers.py:147, in safe_reraise.__exit__(self, type_, value, traceback)
#     146     self._exc_info = None  # remove potential circular references
# --> 147     raise exc_value.with_traceback(exc_tb)
#     148 else:
#
# File ~\AppData\Roaming\Python\Python39\site-packages\sqlalchemy\pool\impl.py:167, in QueuePool._do_get(self)
#     166 try:
# --> 167     return self._create_connection()
#     168 except:
#
# File ~\AppData\Roaming\Python\Python39\site-packages\sqlalchemy\pool\base.py:393, in Pool._create_connection(self)
#     391 """Called by subclasses to create a new ConnectionRecord."""
# --> 393 return _ConnectionRecord(self)
#
# File ~\AppData\Roaming\Python\Python39\site-packages\sqlalchemy\pool\base.py:678, in _ConnectionRecord.__init__(self, pool, connect)
#     677 if connect:
# --> 678     self.__connect()
#     679 self.finalize_callback = deque()
#
# File ~\AppData\Roaming\Python\Python39\site-packages\sqlalchemy\pool\base.py:903, in _ConnectionRecord.__connect(self)
#     902     with util.safe_reraise():
# --> 903         pool.logger.debug("Error on connect(): %s", e)
#     904 else:
#     905     # in SQLAlchemy 1.4 the first_connect event is not used by
#     906     # the engine, so this will usually not be set
#
# File ~\AppData\Roaming\Python\Python39\site-packages\sqlalchemy\util\langhelpers.py:147, in safe_reraise.__exit__(self, type_, value, traceback)
#     146     self._exc_info = None  # remove potential circular references
# --> 147     raise exc_value.with_traceback(exc_tb)
#     148 else:
#
# File ~\AppData\Roaming\Python\Python39\site-packages\sqlalchemy\pool\base.py:898, in _ConnectionRecord.__connect(self)
#     897 self.starttime = time.time()
# --> 898 self.dbapi_connection = connection = pool._invoke_creator(self)
#     899 pool.logger.debug("Created new connection %r", connection)
#
# File ~\AppData\Roaming\Python\Python39\site-packages\sqlalchemy\engine\create.py:637, in create_engine.<locals>.connect(connection_record)
#     635             return connection
# --> 637 return dialect.connect(*cargs, **cparams)
#
# File ~\AppData\Roaming\Python\Python39\site-packages\sqlalchemy\engine\default.py:615, in DefaultDialect.connect(self, *cargs, **cparams)
#     613 def connect(self, *cargs, **cparams):
#     614     # inherits the docstring from interfaces.Dialect.connect
# --> 615     return self.loaded_dbapi.connect(*cargs, **cparams)
#
# OperationalError: ('08001', '[08001] [Microsoft][ODBC SQL Server Driver][DBNETLIB]SQL Server does not exist or access denied. (17) (SQLDriverConnect); [08001] [Microsoft][ODBC SQL Server Driver][DBNETLIB]ConnectionOpen (Connect()). (10061)')
#
# The above exception was the direct cause of the following exception:
#
# OperationalError                          Traceback (most recent call last)
# Cell In[43], line 13
#       1 connection_url = URL.create(
#       2     drivername="mssql+pyodbc",
#       3     username=_username,
#    (...)
#       8     query={"driver": "SQL Server"}
#       9 )
#      11 engine = sqlalchemy.create_engine(connection_url)
# ---> 13 df2= pd.read_sql(query, engine)
#      14 df2.tail()
#
# File D:\ProgramData\anaconda3\envs\mis_data_google\lib\site-packages\pandas\io\sql.py:631, in read_sql(sql, con, index_col, coerce_float, params, parse_dates, columns, chunksize, dtype_backend, dtype)
#     628 if dtype_backend is lib.no_default:
#     629     dtype_backend = "numpy"  # type: ignore[assignment]
# --> 631 with pandasSQL_builder(con) as pandas_sql:
#     632     if isinstance(pandas_sql, SQLiteDatabase):
#     633         return pandas_sql.read_query(
#     634             sql,
#     635             index_col=index_col,
#    (...)
#     641             dtype=dtype,
#     642         )
#
# File D:\ProgramData\anaconda3\envs\mis_data_google\lib\site-packages\pandas\io\sql.py:830, in pandasSQL_builder(con, schema, need_transaction)
#     827     raise ImportError("Using URI string without sqlalchemy installed.")
#     829 if sqlalchemy is not None and isinstance(con, (str, sqlalchemy.engine.Connectable)):
# --> 830     return SQLDatabase(con, schema, need_transaction)
#     832 warnings.warn(
#     833     "pandas only supports SQLAlchemy connectable (engine/connection) or "
#     834     "database string URI or sqlite3 DBAPI2 connection. Other DBAPI2 "
#    (...)
#     837     stacklevel=find_stack_level(),
#     838 )
#     839 return SQLiteDatabase(con)
#
# File D:\ProgramData\anaconda3\envs\mis_data_google\lib\site-packages\pandas\io\sql.py:1537, in SQLDatabase.__init__(self, con, schema, need_transaction)
#    1535     self.exit_stack.callback(con.dispose)
#    1536 if isinstance(con, Engine):
# -> 1537     con = self.exit_stack.enter_context(con.connect())
#    1538 if need_transaction and not con.in_transaction():
#    1539     self.exit_stack.enter_context(con.begin())
#
# File ~\AppData\Roaming\Python\Python39\site-packages\sqlalchemy\engine\base.py:3264, in Engine.connect(self)
#    3241 def connect(self) -> Connection:
#    3242     """Return a new :class:`_engine.Connection` object.
#    3243
#    3244     The :class:`_engine.Connection` acts as a Python context manager, so
#    (...)
#    3261
#    3262     """
# -> 3264     return self._connection_cls(self)
#
# File ~\AppData\Roaming\Python\Python39\site-packages\sqlalchemy\engine\base.py:147, in Connection.__init__(self, engine, connection, _has_events, _allow_revalidate, _allow_autobegin)
#     145         self._dbapi_connection = engine.raw_connection()
#     146     except dialect.loaded_dbapi.Error as err:
# --> 147         Connection._handle_dbapi_exception_noconnection(
#     148             err, dialect, engine
#     149         )
#     150         raise
#     151 else:
#
# File ~\AppData\Roaming\Python\Python39\site-packages\sqlalchemy\engine\base.py:2426, in Connection._handle_dbapi_exception_noconnection(cls, e, dialect, engine, is_disconnect, invalidate_pool_on_disconnect, is_pre_ping)
#    2424 elif should_wrap:
#    2425     assert sqlalchemy_exception is not None
# -> 2426     raise sqlalchemy_exception.with_traceback(exc_info[2]) from e
#    2427 else:
#    2428     assert exc_info[1] is not None
#
# File ~\AppData\Roaming\Python\Python39\site-packages\sqlalchemy\engine\base.py:145, in Connection.__init__(self, engine, connection, _has_events, _allow_revalidate, _allow_autobegin)
#     143 if connection is None:
#     144     try:
# --> 145         self._dbapi_connection = engine.raw_connection()
#     146     except dialect.loaded_dbapi.Error as err:
#     147         Connection._handle_dbapi_exception_noconnection(
#     148             err, dialect, engine
#     149         )
#
# File ~\AppData\Roaming\Python\Python39\site-packages\sqlalchemy\engine\base.py:3288, in Engine.raw_connection(self)
#    3266 def raw_connection(self) -> PoolProxiedConnection:
#    3267     """Return a "raw" DBAPI connection from the connection pool.
#    3268
#    3269     The returned object is a proxied version of the DBAPI
#    (...)
#    3286
#    3287     """
# -> 3288     return self.pool.connect()
#
# File ~\AppData\Roaming\Python\Python39\site-packages\sqlalchemy\pool\base.py:452, in Pool.connect(self)
#     444 def connect(self) -> PoolProxiedConnection:
#     445     """Return a DBAPI connection from the pool.
#     446
#     447     The connection is instrumented such that when its
#    (...)
#     450
#     451     """
# --> 452     return _ConnectionFairy._checkout(self)
#
# File ~\AppData\Roaming\Python\Python39\site-packages\sqlalchemy\pool\base.py:1267, in _ConnectionFairy._checkout(cls, pool, threadconns, fairy)
#    1259 @classmethod
#    1260 def _checkout(
#    1261     cls,
#    (...)
#    1264     fairy: Optional[_ConnectionFairy] = None,
#    1265 ) -> _ConnectionFairy:
#    1266     if not fairy:
# -> 1267         fairy = _ConnectionRecord.checkout(pool)
#    1269         if threadconns is not None:
#    1270             threadconns.current = weakref.ref(fairy)
#
# File ~\AppData\Roaming\Python\Python39\site-packages\sqlalchemy\pool\base.py:716, in _ConnectionRecord.checkout(cls, pool)
#     714     rec = cast(_ConnectionRecord, pool._do_get())
#     715 else:
# --> 716     rec = pool._do_get()
#     718 try:
#     719     dbapi_connection = rec.get_connection()
#
# File ~\AppData\Roaming\Python\Python39\site-packages\sqlalchemy\pool\impl.py:170, in QueuePool._do_get(self)
#     168     except:
#     169         with util.safe_reraise():
# --> 170             self._dec_overflow()
#     171         raise
#     172 else:
#
# File ~\AppData\Roaming\Python\Python39\site-packages\sqlalchemy\util\langhelpers.py:147, in safe_reraise.__exit__(self, type_, value, traceback)
#     145     assert exc_value is not None
#     146     self._exc_info = None  # remove potential circular references
# --> 147     raise exc_value.with_traceback(exc_tb)
#     148 else:
#     149     self._exc_info = None  # remove potential circular references
#
# File ~\AppData\Roaming\Python\Python39\site-packages\sqlalchemy\pool\impl.py:167, in QueuePool._do_get(self)
#     165 if self._inc_overflow():
#     166     try:
# --> 167         return self._create_connection()
#     168     except:
#     169         with util.safe_reraise():
#
# File ~\AppData\Roaming\Python\Python39\site-packages\sqlalchemy\pool\base.py:393, in Pool._create_connection(self)
#     390 def _create_connection(self) -> ConnectionPoolEntry:
#     391     """Called by subclasses to create a new ConnectionRecord."""
# --> 393     return _ConnectionRecord(self)
#
# File ~\AppData\Roaming\Python\Python39\site-packages\sqlalchemy\pool\base.py:678, in _ConnectionRecord.__init__(self, pool, connect)
#     676 self.__pool = pool
#     677 if connect:
# --> 678     self.__connect()
#     679 self.finalize_callback = deque()
#
# File ~\AppData\Roaming\Python\Python39\site-packages\sqlalchemy\pool\base.py:903, in _ConnectionRecord.__connect(self)
#     901 except BaseException as e:
#     902     with util.safe_reraise():
# --> 903         pool.logger.debug("Error on connect(): %s", e)
#     904 else:
#     905     # in SQLAlchemy 1.4 the first_connect event is not used by
#     906     # the engine, so this will usually not be set
#     907     if pool.dispatch.first_connect:
#
# File ~\AppData\Roaming\Python\Python39\site-packages\sqlalchemy\util\langhelpers.py:147, in safe_reraise.__exit__(self, type_, value, traceback)
#     145     assert exc_value is not None
#     146     self._exc_info = None  # remove potential circular references
# --> 147     raise exc_value.with_traceback(exc_tb)
#     148 else:
#     149     self._exc_info = None  # remove potential circular references
#
# File ~\AppData\Roaming\Python\Python39\site-packages\sqlalchemy\pool\base.py:898, in _ConnectionRecord.__connect(self)
#     896 try:
#     897     self.starttime = time.time()
# --> 898     self.dbapi_connection = connection = pool._invoke_creator(self)
#     899     pool.logger.debug("Created new connection %r", connection)
#     900     self.fresh = True
#
# File ~\AppData\Roaming\Python\Python39\site-packages\sqlalchemy\engine\create.py:637, in create_engine.<locals>.connect(connection_record)
#     634         if connection is not None:
#     635             return connection
# --> 637 return dialect.connect(*cargs, **cparams)
#
# File ~\AppData\Roaming\Python\Python39\site-packages\sqlalchemy\engine\default.py:615, in DefaultDialect.connect(self, *cargs, **cparams)
#     613 def connect(self, *cargs, **cparams):
#     614     # inherits the docstring from interfaces.Dialect.connect
# --> 615     return self.loaded_dbapi.connect(*cargs, **cparams)
#
# OperationalError: (pyodbc.OperationalError) ('08001', '[08001] [Microsoft][ODBC SQL Server Driver][DBNETLIB]SQL Server does not exist or access denied. (17) (SQLDriverConnect); [08001] [Microsoft][ODBC SQL Server Driver][DBNETLIB]ConnectionOpen (Connect()). (10061)')
# (Background on this error at: https://sqlalche.me/e/20/e3q8)
